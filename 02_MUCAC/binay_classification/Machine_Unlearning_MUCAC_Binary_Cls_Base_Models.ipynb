# %% [markdown]
# #### <b>Download the Original Datasets</b>
#
# * <b>CelebA-HQ Dataset</b>: A dataset consisting of 30,000 "human face" images.
#     * This dataset has approximately 3GB of data in size and is one of the most widely used face datasets worldwide.
# * <b>CelebA-HQ Identity Dataset</b>: A dataset that provides information about <b>who the individuals (subjects) are</b> for each facial image file.
# * <b>CelebA-HQ Attribute Dataset</b>: A dataset that provides attribute information for each facial image file.
#     * This attribute information includes <b>gender</b>, <b>smiling</b>, and <b>age</b>, which we will be used for a multi-label task.

# %%
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/Eb37jNPPA7hHl0fmktYqcV8B-qmPLx-ZKYQ1eFk4UPBV_A?download=1 -O CelebAMask-HQ.zip
# !wget https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVRoUY8_txRFv56-KWvZrksBDWbD6adkjBxwwRN7qAC6bg?download=1 -O CelebA-HQ-identity.txt
# !wget https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVrdIrPOkR1OlEWBVK8lE3AB9bFh741GnKBkNgPa8trNuA?download=1 -O CelebA-HQ-attribute.txt
# Out:
# --2023-11-03 15:13:31--  https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/Eb37jNPPA7hHl0fmktYqcV8B-qmPLx-ZKYQ1eFk4UPBV_A?download=1
# Resolving postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8f8::10, ...
# Connecting to postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/dongbinna_postech_ac_kr/Documents/Research/datasets/CelebAMask-HQ/CelebAMask-HQ.zip?ga=1 [following]
# --2023-11-03 15:13:32--  https://postechackr-my.sharepoint.com/personal/dongbinna_postech_ac_kr/Documents/Research/datasets/CelebAMask-HQ/CelebAMask-HQ.zip?ga=1
# Reusing existing connection to postechackr-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3153930546 (2.9G) [application/x-zip-compressed]
# Saving to: ‘CelebAMask-HQ.zip’
#
# CelebAMask-HQ.zip   100%[===================>]   2.94G  19.0MB/s    in 4m 8s
#
# 2023-11-03 15:17:42 (12.1 MB/s) - ‘CelebAMask-HQ.zip’ saved [3153930546/3153930546]
#
# --2023-11-03 15:17:42--  https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVRoUY8_txRFv56-KWvZrksBDWbD6adkjBxwwRN7qAC6bg?download=1
# Resolving postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8f8::10, ...
# Connecting to postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/dongbinna_postech_ac_kr/Documents/Research/datasets/CelebAMask-HQ/CelebA-HQ-identity.txt?ga=1 [following]
# --2023-11-03 15:17:44--  https://postechackr-my.sharepoint.com/personal/dongbinna_postech_ac_kr/Documents/Research/datasets/CelebAMask-HQ/CelebA-HQ-identity.txt?ga=1
# Reusing existing connection to postechackr-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 427557 (418K) [text/plain]
# Saving to: ‘CelebA-HQ-identity.txt’
#
# CelebA-HQ-identity. 100%[===================>] 417.54K   419KB/s    in 1.0s
#
# 2023-11-03 15:17:45 (419 KB/s) - ‘CelebA-HQ-identity.txt’ saved [427557/427557]
#
# --2023-11-03 15:17:45--  https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVrdIrPOkR1OlEWBVK8lE3AB9bFh741GnKBkNgPa8trNuA?download=1
# Resolving postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8f8::10, ...
# Connecting to postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/dongbinna_postech_ac_kr/Documents/Research/datasets/CelebAMask-HQ/CelebA-HQ-attribute.txt?ga=1 [following]
# --2023-11-03 15:17:46--  https://postechackr-my.sharepoint.com/personal/dongbinna_postech_ac_kr/Documents/Research/datasets/CelebAMask-HQ/CelebA-HQ-attribute.txt?ga=1
# Reusing existing connection to postechackr-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3622218 (3.5M) [text/plain]
# Saving to: ‘CelebA-HQ-attribute.txt’
#
# CelebA-HQ-attribute 100%[===================>]   3.45M   919KB/s    in 3.8s
#
# 2023-11-03 15:17:50 (919 KB/s) - ‘CelebA-HQ-attribute.txt’ saved [3622218/3622218]

# %%
# %%capture
# !rm -rf ./CelebAMask-HQ
# !unzip CelebAMask-HQ.zip

# %% [markdown]
# #### <b>Load Libraries</b>
#
# * Load various useful python libraries for the experiments.

# %%
import os
import time
import random
import glob
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, transforms, models
import torchvision.transforms.functional as TF
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn import linear_model, model_selection

# %%
def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

def compute_losses(net, loader):
    criterion = nn.CrossEntropyLoss(reduction="none")
    all_losses = []

    for inputs, labels in loader:
        targets = labels
        inputs, targets = inputs.cuda(), targets.cuda()

        logits = net(inputs)

        losses = criterion(logits, targets).cpu().detach().numpy()
        #losses = criterion(logits, targets).numpy(force=True)
        for l in losses:
            all_losses.append(l)

    return np.array(all_losses)

def simple_mia(sample_loss, members, n_splits=10, random_state=0):
    unique_members = np.unique(members)
    if not np.all(unique_members == np.array([0, 1])):
        raise ValueError("members should only have 0 and 1s")

    attack_model = linear_model.LogisticRegression()
    cv = model_selection.StratifiedShuffleSplit(
        n_splits=n_splits, random_state=random_state
    )
    return model_selection.cross_val_score(
        attack_model, sample_loss, members, cv=cv, scoring="accuracy"
    )


def cal_mia(model):

    set_seed(42)

    forget_losses = compute_losses(model, forget_dataloader_test)
    unseen_losses = compute_losses(model, unseen_dataloader)

    np.random.shuffle(forget_losses)
    forget_losses = forget_losses[: len(unseen_losses)]

    samples_mia = np.concatenate((unseen_losses, forget_losses)).reshape((-1, 1))
    labels_mia = [0] * len(unseen_losses) + [1] * len(forget_losses)

    mia_scores = simple_mia(samples_mia, labels_mia)
    forgetting_score = abs(0.5 - mia_scores.mean())

    return {'MIA': mia_scores.mean(), 'Forgeting Score': forgetting_score}


@torch.no_grad()
def evaluation(model, data_loader):
    model.eval()
    with torch.no_grad():
        running_loss = 0.
        running_corrects = 0

        for inputs, labels in data_loader:
            inputs = inputs.cuda()
            labels = labels.cuda()

            outputs = model(inputs)  # Use the passed model argument here
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Use data_loader's dataset length for normalization
        epoch_loss = running_loss / len(data_loader.dataset)
        epoch_loss = round(epoch_loss, 3)
        epoch_acc = running_corrects.item() / len(data_loader.dataset)

        return {'Loss': epoch_loss, 'Acc': epoch_acc}

# %% [markdown]
# #### <b>Load Identity Mapping</b>
# * Check which person each file name is associated with.
# * There are a total of 6,217 individuals (subjects) among the 30,000 files.

# %%
path = "./"

# %%
identities = {}

# (Image File Name, Subject Identity Information)
with open(path + 'CelebA-HQ-identity.txt') as f:
    lines = f.readlines()
    for line in lines:
        file_name, identity = line.strip().split()
        identities[file_name] = identity

print(f'There are {len(set(identities.values()))} identities.')
print(f'There are {len(identities.keys())} images.')
# Out:
# There are 6217 identities.
# There are 30000 images.

# %% [markdown]
# #### <b>Choose Single Label to Use</b>
# * "male": 21,
# * "smiling": 32,
# * "young": 40

# %%
label_map = {}

label_num = 40  # "male": 21, "smiling": 32, "young": 40

with open(path + 'CelebA-HQ-attribute.txt') as f:
    lines = f.readlines()
    for line in lines[2:]:
        splited = line.strip().split()
        file_name, label = splited[0], splited[label_num]
        label_map[file_name] = label

print(f'There are {len(set(label_map.values()))} classes.')
print(f'There are {len(label_map.keys())} images.')
# Out:
# There are 2 classes.
# There are 30000 images.

# %% [markdown]
# #### <b>Split the Dataset</b>
# * <b>Training dataset  $\mathcal{D}_{train}$</b>: 25,933 images.
# * <b>Test dataset $\mathcal{D}_{test}$</b>: 2,065 images.
# * <b>Unseen dataset $\mathcal{D}_{unseen}$</b>: 2,002 images.

# %%
source_root = path + 'CelebAMask-HQ/CelebA-HQ-img/'

train_index = 190
retain_index = 1250
unseen_index = 4855

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity >= train_index and identity < unseen_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []
        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < train_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class ForgetDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity >= train_index and identity < retain_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class RetainDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index and identity >= retain_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class UnseenDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []
        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0
            self.labels.append((label, identity))
            self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
train_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.RandomHorizontalFlip(),
    transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.ToTensor()
])

unseen_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.ToTensor()
])

train_set = TrainDataset(transform=train_transform)
test_set = TestDataset(transform=test_transform)
forget_set_train = ForgetDataset(transform=train_transform)
forget_set_test = ForgetDataset(transform=test_transform)
retain_set_train = RetainDataset(transform=train_transform)
retain_set_test = RetainDataset(transform=test_transform)
unseen_set = UnseenDataset(transform=unseen_transform)

# %%
print('Train dataset size:', len(train_set))
print('Test dataset size:', len(test_set))
print('Forget dataset size:', len(forget_set_train))
print('Retain dataset size:', len(retain_set_train))
print('Unseen dataset size:', len(unseen_set))
# Out:
# Train dataset size: 25846
# Test dataset size: 2053
# Forget dataset size: 10135
# Retain dataset size: 15711
# Unseen dataset size: 2001

# %% [markdown]
# * In the NeurIPS Competition setting, when performing machine unlearning, training is done with 'retain' and 'forget', so augmentation can be applied. However, it should never be applied during evaluation.

# %%
train_dataloader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True, num_workers=2, pin_memory=True)
test_dataloader = torch.utils.data.DataLoader(test_set, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
forget_dataloader_train = torch.utils.data.DataLoader(forget_set_train, batch_size=64, shuffle=True, num_workers=2, pin_memory=True)
forget_dataloader_test = torch.utils.data.DataLoader(forget_set_test, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)
retain_dataloader_train = torch.utils.data.DataLoader(retain_set_train, batch_size=64, shuffle=True, num_workers=2, pin_memory=True)
retain_dataloader_test = torch.utils.data.DataLoader(retain_set_test, batch_size=64, shuffle=False, num_workers=2,pin_memory=True)
unseen_dataloader = torch.utils.data.DataLoader(unseen_set, batch_size=64, shuffle=False, num_workers=2, pin_memory=True)

# %%
train_image_paths = TrainDataset().image_paths
test_image_paths = TestDataset().image_paths
forget_image_paths = ForgetDataset().image_paths
retain_image_paths = RetainDataset().image_paths
unseen_image_paths = UnseenDataset().image_paths

train_test_overlap = len(set(train_image_paths) & set(test_image_paths))
train_forget_overlap = len(set(train_image_paths) & set(forget_image_paths))
train_retain_overlap = len(set(train_image_paths) & set(retain_image_paths))
train_unseen_overlap = len(set(train_image_paths) & set(unseen_image_paths))
test_forget_overlap = len(set(test_image_paths) & set(forget_image_paths))
test_retain_overlap = len(set(test_image_paths) & set(retain_image_paths))
test_unseen_overlap = len(set(test_image_paths) & set(unseen_image_paths))
forget_retain_overlap = len(set(forget_image_paths) & set(retain_image_paths))
forget_unseen_overlap = len(set(forget_image_paths) & set(unseen_image_paths))
retain_unseen_overlap = len(set(retain_image_paths) & set(unseen_image_paths))

overlap_dict = {
    'train_test': train_test_overlap,
    'train_forget': train_forget_overlap,
    'train_retain': train_retain_overlap,
    'train_unseen': train_unseen_overlap,
    'test_forget': test_forget_overlap,
    'test_retain': test_retain_overlap,
    'test_unseen': test_unseen_overlap,
    'forget_retain': forget_retain_overlap,
    'forget_unseen': forget_unseen_overlap,
    'retain_unseen': retain_unseen_overlap
}
overlap_dict
# Out:
# {'train_test': 0,
#  'train_forget': 10135,
#  'train_retain': 15711,
#  'train_unseen': 0,
#  'test_forget': 0,
#  'test_retain': 0,
#  'test_unseen': 0,
#  'forget_retain': 0,
#  'forget_unseen': 0,
#  'retain_unseen': 0}

# %% [markdown]
# #### <b>Imgae Visualization</b>

# %%
if label_num == 21:
    label_convert = {0: "F", 1: "M"}
elif label_num == 32:
    label_convert = {0: "unsmiling", 1: "smiling"}
if label_num == 40:
    label_convert = {0: "old", 1: "young"}

# %%
def show_images(images, labels, nrow=6, save_path=None):
    n_images = len(images)
    nrows = n_images // nrow + (n_images % nrow > 0)

    fig, axs = plt.subplots(nrows, nrow, figsize=(14.5, 2.3 * nrows), frameon=False)
    axs = axs.flatten() if n_images > 1 else [axs]

    for idx, (img, label) in enumerate(zip(images, labels)):
        ax = axs[idx]
        img_np = img.numpy().transpose((1, 2, 0))
        ax.imshow(img_np)
        ax.axis('off')

        ax.text(5, 5, label, color='white', fontsize=13,  ha='left', va='top',
                bbox=dict(facecolor='black', alpha=0.5, boxstyle='round,pad=0.1'))

    plt.tight_layout(pad=0)

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)

    plt.show()

iterator = iter(test_dataloader)
imgs, labels = next(iterator)

label_strs = [label_convert[label.item()] for label in labels[0:12]]

show_images(imgs[0:12], label_strs, nrow=6)

# %% [markdown]
# #### <b>Train the "Original Model"</b>
#
# * Train the Original model to serve as the base model for performing Machine Unlearning

# %%
learning_rate = 0.01
log_step = 30

model = models.resnet18(pretrained=False)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
def train(model, dataloader):
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Training]')
    model.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0
    log_step = 20

    for i, (imgs, labels) in enumerate(dataloader):
        imgs = imgs.cuda()
        labels = labels.cuda()

        outputs = model(imgs)
        optimizer.zero_grad()
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total += labels.size(0)
        running_loss += loss.item() * imgs.size(0)
        running_corrects += torch.sum(preds == labels)

        if (i + 1) % log_step == 0:
            current_loss = running_loss / total
            current_acc = running_corrects.double() / total
            print(f'[Batch: {i + 1}] running train loss: {current_loss:.4f}, running train accuracy: {current_acc:.4f}')

    epoch_loss = running_loss / total
    epoch_acc = running_corrects.double() / total
    print(f'train loss: {epoch_loss:.4f}, accuracy: {epoch_acc:.4f}')
    print("elapsed time:", time.time() - start_time)
    return epoch_loss, epoch_acc.item()


def test(model, dataloader):
    start_time = time.time()
    print('[Test]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0
    log_step=20

    for i, (imgs, labels) in enumerate(dataloader):
        imgs = imgs.cuda()
        labels = labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.size(0)
        running_loss += loss.item() * imgs.size(0)
        running_corrects += torch.sum(preds == labels)

        if (i == 0) or ((i + 1) % log_step == 0):
            current_loss = running_loss / total
            current_acc = running_corrects.double() / total
            print(f'[Batch: {i + 1}] running test loss: {current_loss:.4f}, running test accuracy: {current_acc:.4f}')

    epoch_loss = running_loss / total
    epoch_acc = running_corrects.double() / total
    print(f'test loss: {epoch_loss:.4f}, accuracy: {epoch_acc:.4f}')
    print("elapsed time:", time.time() - start_time)
    return epoch_loss, epoch_acc.item()

# %%
num_original_epochs = 10
best_test_acc = 0
best_epoch = 0

history = []
accuracy = []
num_original_epochs = 10
for epoch in range(num_original_epochs):
    train_loss, train_acc = train(model, train_dataloader)
    test_loss, test_acc = test(model, test_dataloader)
    history.append((train_loss, test_loss))
    accuracy.append((train_acc, test_acc))

    if test_acc > best_test_acc:
        print("[Info] best test accuracy!")
        best_test_acc = test_acc
        best_epoch = epoch
        torch.save(model.state_dict(), f'best_checkpoint_epoch_{epoch + 1}_gender.pth')

torch.save(model.state_dict(), f'last_checkpoint_epoch_{num_original_epochs}_gender.pth')
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.6504, running train accuracy: 0.7000
# [Batch: 40] running train loss: 0.6131, running train accuracy: 0.7203
# [Batch: 60] running train loss: 0.6153, running train accuracy: 0.7286
# [Batch: 80] running train loss: 0.6657, running train accuracy: 0.7254
# [Batch: 100] running train loss: 0.6421, running train accuracy: 0.7320
# [Batch: 120] running train loss: 0.6173, running train accuracy: 0.7436
# [Batch: 140] running train loss: 0.6080, running train accuracy: 0.7440
# [Batch: 160] running train loss: 0.5903, running train accuracy: 0.7501
# [Batch: 180] running train loss: 0.5764, running train accuracy: 0.7544
# [Batch: 200] running train loss: 0.5674, running train accuracy: 0.7589
# [Batch: 220] running train loss: 0.5610, running train accuracy: 0.7609
# [Batch: 240] running train loss: 0.5545, running train accuracy: 0.7620
# [Batch: 260] running train loss: 0.5473, running train accuracy: 0.7655
# [Batch: 280] running train loss: 0.5412, running train accuracy: 0.7676
# [Batch: 100] running train loss: 0.3113, running train accuracy: 0.8738
# [Batch: 120] running train loss: 0.3150, running train accuracy: 0.8723
# [Batch: 140] running train loss: 0.3146, running train accuracy: 0.8715
# [Batch: 160] running train loss: 0.3141, running train accuracy: 0.8706
# [Batch: 180] running train loss: 0.3132, running train accuracy: 0.8712
# [Batch: 200] running train loss: 0.3100, running train accuracy: 0.8727
# [Batch: 220] running train loss: 0.3098, running train accuracy: 0.8722
# [Batch: 240] running train loss: 0.3108, running train accuracy: 0.8719
# [Batch: 260] running train loss: 0.3136, running train accuracy: 0.8703
# [Batch: 280] running train loss: 0.3128, running train accuracy: 0.8704
# [Batch: 300] running train loss: 0.3110, running train accuracy: 0.8711
# [Batch: 320] running train loss: 0.3100, running train accuracy: 0.8714
# [Batch: 340] running train loss: 0.3093, running train accuracy: 0.8721
# [Batch: 360] running train loss: 0.3074, running train accuracy: 0.8730
# [Batch: 380] running train loss: 0.3079, running train accuracy: 0.8730
# [Batch: 400] running train loss: 0.3085, running train accuracy: 0.8727
# train loss: 0.3085, accuracy: 0.8727
# elapsed time: 109.87256145477295
# [Test]
# [Batch: 1] running test loss: 0.2759, running test accuracy: 0.8594
# [Batch: 20] running test loss: 0.2477, running test accuracy: 0.9070
# test loss: 0.2522, accuracy: 0.9060
# elapsed time: 8.403605461120605
# [Info] best test accuracy!
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.2984, running train accuracy: 0.8789
# [Batch: 40] running train loss: 0.2976, running train accuracy: 0.8773
# [Batch: 60] running train loss: 0.2870, running train accuracy: 0.8823
# [Batch: 80] running train loss: 0.2809, running train accuracy: 0.8842
# [Batch: 100] running train loss: 0.2787, running train accuracy: 0.8848
# [Batch: 120] running train loss: 0.2759, running train accuracy: 0.8863
# [Batch: 140] running train loss: 0.2785, running train accuracy: 0.8854
# [Batch: 160] running train loss: 0.2815, running train accuracy: 0.8841
# [Batch: 180] running train loss: 0.2815, running train accuracy: 0.8838
# [Batch: 200] running train loss: 0.2823, running train accuracy: 0.8836
# [Batch: 220] running train loss: 0.2821, running train accuracy: 0.8841
# [Batch: 240] running train loss: 0.2846, running train accuracy: 0.8838
# [Batch: 260] running train loss: 0.2865, running train accuracy: 0.8826
# [Batch: 280] running train loss: 0.2863, running train accuracy: 0.8831
# [Batch: 300] running train loss: 0.2855, running train accuracy: 0.8834
# [Batch: 320] running train loss: 0.2879, running train accuracy: 0.8819
# [Batch: 340] running train loss: 0.2904, running train accuracy: 0.8809
# [Batch: 360] running train loss: 0.2904, running train accuracy: 0.8804
# [Batch: 380] running train loss: 0.2921, running train accuracy: 0.8803
# [Batch: 400] running train loss: 0.2921, running train accuracy: 0.8807
# train loss: 0.2918, accuracy: 0.8807
# elapsed time: 111.95128417015076
# [Test]
# [Batch: 1] running test loss: 1.3304, running test accuracy: 0.7969
# [Batch: 20] running test loss: 1.0500, running test accuracy: 0.8313
# test loss: 1.0365, accuracy: 0.8305
# elapsed time: 7.590157747268677
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.2787, running train accuracy: 0.8898
# [Batch: 40] running train loss: 0.2951, running train accuracy: 0.8805
# [Batch: 60] running train loss: 0.2901, running train accuracy: 0.8823
# [Batch: 80] running train loss: 0.2869, running train accuracy: 0.8826
# [Batch: 100] running train loss: 0.2859, running train accuracy: 0.8822
# [Batch: 120] running train loss: 0.2822, running train accuracy: 0.8820
# [Batch: 140] running train loss: 0.2878, running train accuracy: 0.8794
# [Batch: 160] running train loss: 0.2897, running train accuracy: 0.8790
# [Batch: 180] running train loss: 0.2901, running train accuracy: 0.8790
# [Batch: 200] running train loss: 0.2880, running train accuracy: 0.8811
# [Batch: 220] running train loss: 0.2883, running train accuracy: 0.8818
# [Batch: 240] running train loss: 0.2877, running train accuracy: 0.8824
# [Batch: 260] running train loss: 0.2861, running train accuracy: 0.8829
# [Batch: 280] running train loss: 0.2862, running train accuracy: 0.8829
# [Batch: 300] running train loss: 0.2876, running train accuracy: 0.8823
# [Batch: 320] running train loss: 0.2871, running train accuracy: 0.8825
# [Batch: 340] running train loss: 0.2868, running train accuracy: 0.8826
# [Batch: 360] running train loss: 0.2871, running train accuracy: 0.8826
# [Batch: 380] running train loss: 0.2875, running train accuracy: 0.8826
# [Batch: 400] running train loss: 0.2890, running train accuracy: 0.8816
# train loss: 0.2889, accuracy: 0.8815
# elapsed time: 109.67236423492432
# [Test]
# [Batch: 1] running test loss: 0.4063, running test accuracy: 0.8906
# [Batch: 20] running test loss: 0.4490, running test accuracy: 0.7969
# test loss: 0.4506, accuracy: 0.7940
# elapsed time: 8.146046876907349
# [Epoch: 10 - Training]
# [Batch: 20] running train loss: 0.2648, running train accuracy: 0.8891
# [Batch: 40] running train loss: 0.2692, running train accuracy: 0.8883
# [Batch: 60] running train loss: 0.2769, running train accuracy: 0.8862
# [Batch: 80] running train loss: 0.2804, running train accuracy: 0.8830
# [Batch: 100] running train loss: 0.2804, running train accuracy: 0.8823
# [Batch: 120] running train loss: 0.2792, running train accuracy: 0.8835
# [Batch: 140] running train loss: 0.2809, running train accuracy: 0.8828
# [Batch: 160] running train loss: 0.2807, running train accuracy: 0.8821
# [Batch: 180] running train loss: 0.2827, running train accuracy: 0.8820
# [Batch: 200] running train loss: 0.2814, running train accuracy: 0.8823
# [Batch: 220] running train loss: 0.2798, running train accuracy: 0.8827
# [Batch: 240] running train loss: 0.2782, running train accuracy: 0.8829
# [Batch: 260] running train loss: 0.2768, running train accuracy: 0.8837
# [Batch: 280] running train loss: 0.2779, running train accuracy: 0.8832
# [Batch: 300] running train loss: 0.2778, running train accuracy: 0.8834
# [Batch: 320] running train loss: 0.2789, running train accuracy: 0.8832
# [Batch: 340] running train loss: 0.2788, running train accuracy: 0.8831
# [Batch: 360] running train loss: 0.2788, running train accuracy: 0.8828
# [Batch: 380] running train loss: 0.2794, running train accuracy: 0.8829
# [Batch: 400] running train loss: 0.2794, running train accuracy: 0.8832
# train loss: 0.2795, accuracy: 0.8832
# elapsed time: 109.53961062431335
# [Test]
# [Batch: 1] running test loss: 0.2852, running test accuracy: 0.8750
# [Batch: 20] running test loss: 0.2462, running test accuracy: 0.9117
# test loss: 0.2461, accuracy: 0.9104
# elapsed time: 8.18552041053772
# [Info] best test accuracy!

# %%
import matplotlib.pyplot as plt

train_losses, test_losses = zip(*history)
train_accuracies, test_accuracies = zip(*accuracy)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Test Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b>(Option) Load the Pre-trained Original Model</b>
#
# * We can easily download the pre-trained original model, rather than training the original model from scratch.
# * <b>Download Link</b>:
#     * gender: https://drive.google.com/file/d/1BzvUyFBHWQpTseBY8N6GaT1RrlhiTgZp/view?usp=drive_link
#     * young: https://drive.google.com/file/d/15BmYjzvXs_57BcvN6haAgWJ2fYdSZfjW/view?usp=drive_link
#     * smiling: https://drive.google.com/file/d/1lr0ozk9AUzm9ybqMbT7ixGnRdDrOUqhe/view?usp=drive_link

# %%
# male vs female
# !gdown https://drive.google.com/uc?id=1BzvUyFBHWQpTseBY8N6GaT1RrlhiTgZp -O pre_trained_checkpoint.pth
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BzvUyFBHWQpTseBY8N6GaT1RrlhiTgZp
# To: /content/pre_trained_checkpoint.pth
# 100% 44.8M/44.8M [00:00<00:00, 186MB/s]

# %%
# young vs old
# !gdown https://drive.google.com/uc?id=15BmYjzvXs_57BcvN6haAgWJ2fYdSZfjW -O pre_trained_checkpoint.pth
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15BmYjzvXs_57BcvN6haAgWJ2fYdSZfjW
# To: /content/pre_trained_checkpoint.pth
# 100% 44.8M/44.8M [00:00<00:00, 90.4MB/s]

# %%
# smiling vs unsmiling
# !gdown https://drive.google.com/uc?id=1lr0ozk9AUzm9ybqMbT7ixGnRdDrOUqhe -O pre_trained_checkpoint.pth
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1lr0ozk9AUzm9ybqMbT7ixGnRdDrOUqhe
# To: /content/pre_trained_checkpoint.pth
# 100% 44.8M/44.8M [00:00<00:00, 270MB/s]

# %% [markdown]
# <b>Final Test</b>

# %%
model = models.resnet18(pretrained=False)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
model = model.cuda()
# model_path = f'last_checkpoint_epoch_{num_original_epochs}_gender.pth' # If you trian the original model from scratch.
model_path = f'pre_trained_checkpoint.pth'  # downloaded model
model.load_state_dict(torch.load(model_path))

test_loss, test_acc = test(model, test_dataloader)
print("test loss:", test_loss)
print("test acc:", test_acc)
# Out:
# [Test]
# [Batch: 1] running test loss: 0.2548, running test accuracy: 0.9062
# [Batch: 20] running test loss: 0.2351, running test accuracy: 0.9055
# test loss: 0.2339, accuracy: 0.9084
# elapsed time: 7.59802770614624
# test loss: 0.23394584203573535
# test acc: 0.9084266926449099

# %% [markdown]
# #### <b> Train the "Retrained Model"</b>
# * A model trained on only the retain dataset from scratch, excluding the forget dataset.
# * This model can serve as a proxy ground-truth for calculating the potential ground-truth (1) model utility and (2) forgetting score.

# %%
retrained_model = models.resnet18(pretrained=False)
num_features = retrained_model.fc.in_features
retrained_model.fc = nn.Linear(num_features, 2)
retrained_model = retrained_model.cuda()

criterion = nn.CrossEntropyLoss().cuda()
optimizer = optim.SGD(retrained_model.parameters(), lr=0.001)

# %%
learning_rate = 0.01
best_test_acc = 0
best_epoch = 0

history = []
accuracy = []
num_original_epochs = 10
for epoch in range(num_original_epochs):
    train_loss, train_acc = train(retrained_model, retain_dataloader_train)
    test_loss, test_acc = test(retrained_model, test_dataloader)
    history.append((train_loss, test_loss))
    accuracy.append((train_acc, test_acc))
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.5818, running train accuracy: 0.7516
# [Batch: 40] running train loss: 0.5703, running train accuracy: 0.7555
# [Batch: 60] running train loss: 0.5710, running train accuracy: 0.7534
# [Batch: 80] running train loss: 0.5624, running train accuracy: 0.7580
# [Batch: 100] running train loss: 0.5600, running train accuracy: 0.7581
# [Batch: 120] running train loss: 0.5573, running train accuracy: 0.7583
# [Batch: 140] running train loss: 0.5584, running train accuracy: 0.7574
# [Batch: 160] running train loss: 0.5577, running train accuracy: 0.7561
# [Batch: 180] running train loss: 0.5575, running train accuracy: 0.7554
# [Batch: 200] running train loss: 0.5568, running train accuracy: 0.7553
# [Batch: 220] running train loss: 0.5580, running train accuracy: 0.7536
# [Batch: 240] running train loss: 0.5583, running train accuracy: 0.7525
# train loss: 0.5583, accuracy: 0.7523
# elapsed time: 61.229525327682495
# [Test]
# [Batch: 1] running test loss: 0.5097, running test accuracy: 0.7812
# [Batch: 20] running test loss: 0.4751, running test accuracy: 0.8258
# test loss: 0.4755, accuracy: 0.8261
# elapsed time: 7.50146222114563
# [Epoch: 2 - Training]
# [Batch: 20] running train loss: 0.5641, running train accuracy: 0.7453
# [Batch: 40] running train loss: 0.5508, running train accuracy: 0.7551
# [Batch: 60] running train loss: 0.5464, running train accuracy: 0.7565
# [Batch: 80] running train loss: 0.5480, running train accuracy: 0.7551
# [Batch: 100] running train loss: 0.5479, running train accuracy: 0.7545
# [Batch: 120] running train loss: 0.5486, running train accuracy: 0.7526
# [Batch: 140] running train loss: 0.5502, running train accuracy: 0.7503
# [Batch: 160] running train loss: 0.5502, running train accuracy: 0.7497
# [Batch: 180] running train loss: 0.5502, running train accuracy: 0.7495
# [Batch: 200] running train loss: 0.5481, running train accuracy: 0.7510
# [Batch: 220] running train loss: 0.5467, running train accuracy: 0.7518
# [Batch: 240] running train loss: 0.5460, running train accuracy: 0.7523
# train loss: 0.5461, accuracy: 0.7523
# elapsed time: 64.48777770996094
# [Test]
# [Batch: 1] running test loss: 0.4930, running test accuracy: 0.7812
# [Batch: 20] running test loss: 0.4685, running test accuracy: 0.8258
# test loss: 0.4690, accuracy: 0.8261
# elapsed time: 8.086159229278564
# [Epoch: 3 - Training]
# [Batch: 20] running train loss: 0.5383, running train accuracy: 0.7523
# [Batch: 40] running train loss: 0.5383, running train accuracy: 0.7520
# [Batch: 60] running train loss: 0.5392, running train accuracy: 0.7516
# [Batch: 80] running train loss: 0.5363, running train accuracy: 0.7537
# [Batch: 100] running train loss: 0.5369, running train accuracy: 0.7536
# [Batch: 120] running train loss: 0.5395, running train accuracy: 0.7500
# [Batch: 140] running train loss: 0.5379, running train accuracy: 0.7516
# [Batch: 160] running train loss: 0.5392, running train accuracy: 0.7506
# [Batch: 180] running train loss: 0.5399, running train accuracy: 0.7500
# [Batch: 200] running train loss: 0.5405, running train accuracy: 0.7492
# [Batch: 220] running train loss: 0.5398, running train accuracy: 0.7506
# [Batch: 240] running train loss: 0.5369, running train accuracy: 0.7525
# train loss: 0.5368, accuracy: 0.7524
# elapsed time: 65.6253502368927
# [Test]
# [Batch: 1] running test loss: 0.4924, running test accuracy: 0.7812
# [Batch: 20] running test loss: 0.4540, running test accuracy: 0.8258
# test loss: 0.4531, accuracy: 0.8261
# elapsed time: 8.134043455123901
# [Epoch: 4 - Training]
# [Batch: 20] running train loss: 0.5151, running train accuracy: 0.7609
# [Batch: 40] running train loss: 0.5187, running train accuracy: 0.7566
# [Batch: 60] running train loss: 0.5312, running train accuracy: 0.7479
# [Batch: 80] running train loss: 0.5297, running train accuracy: 0.7500
# [Batch: 100] running train loss: 0.5279, running train accuracy: 0.7531
# [Batch: 120] running train loss: 0.5275, running train accuracy: 0.7534
# [Batch: 140] running train loss: 0.5295, running train accuracy: 0.7519
# [Batch: 160] running train loss: 0.5258, running train accuracy: 0.7541
# [Batch: 180] running train loss: 0.5238, running train accuracy: 0.7556
# [Batch: 200] running train loss: 0.5253, running train accuracy: 0.7541
# [Batch: 220] running train loss: 0.5256, running train accuracy: 0.7541
# [Batch: 240] running train loss: 0.5250, running train accuracy: 0.7544
# train loss: 0.5256, accuracy: 0.7536
# elapsed time: 67.0797655582428
# [Test]
# [Batch: 1] running test loss: 0.4890, running test accuracy: 0.7812
# [Batch: 20] running test loss: 0.4734, running test accuracy: 0.8281
# test loss: 0.4708, accuracy: 0.8285
# elapsed time: 8.175727128982544
# [Epoch: 5 - Training]
# [Batch: 20] running train loss: 0.5118, running train accuracy: 0.7641
# [Batch: 40] running train loss: 0.5171, running train accuracy: 0.7633
# [Batch: 60] running train loss: 0.5133, running train accuracy: 0.7643
# [Batch: 80] running train loss: 0.5153, running train accuracy: 0.7615
# [Batch: 100] running train loss: 0.5136, running train accuracy: 0.7622
# [Batch: 120] running train loss: 0.5148, running train accuracy: 0.7615
# [Batch: 140] running train loss: 0.5167, running train accuracy: 0.7593
# [Batch: 160] running train loss: 0.5150, running train accuracy: 0.7605
# [Batch: 180] running train loss: 0.5176, running train accuracy: 0.7589
# [Batch: 200] running train loss: 0.5163, running train accuracy: 0.7600
# [Batch: 220] running train loss: 0.5156, running train accuracy: 0.7600
# [Batch: 240] running train loss: 0.5157, running train accuracy: 0.7590
# train loss: 0.5161, accuracy: 0.7583
# elapsed time: 66.31975793838501
# [Test]
# [Batch: 1] running test loss: 0.4840, running test accuracy: 0.7812
# [Batch: 20] running test loss: 0.4575, running test accuracy: 0.8234
# test loss: 0.4555, accuracy: 0.8222
# elapsed time: 8.152667045593262
# [Epoch: 6 - Training]
# [Batch: 20] running train loss: 0.5173, running train accuracy: 0.7563
# [Batch: 40] running train loss: 0.5091, running train accuracy: 0.7590
# [Batch: 60] running train loss: 0.5108, running train accuracy: 0.7583
# [Batch: 80] running train loss: 0.5082, running train accuracy: 0.7604
# [Batch: 100] running train loss: 0.5061, running train accuracy: 0.7620
# [Batch: 120] running train loss: 0.5065, running train accuracy: 0.7612
# [Batch: 140] running train loss: 0.5031, running train accuracy: 0.7641
# [Batch: 160] running train loss: 0.5046, running train accuracy: 0.7640
# [Batch: 180] running train loss: 0.5056, running train accuracy: 0.7632
# [Batch: 200] running train loss: 0.5070, running train accuracy: 0.7624
# [Batch: 220] running train loss: 0.5059, running train accuracy: 0.7641
# [Batch: 240] running train loss: 0.5044, running train accuracy: 0.7656
# train loss: 0.5040, accuracy: 0.7656
# elapsed time: 66.0722815990448
# [Test]
# [Batch: 1] running test loss: 0.4767, running test accuracy: 0.7656
# [Batch: 20] running test loss: 0.4378, running test accuracy: 0.8289
# test loss: 0.4346, accuracy: 0.8295
# elapsed time: 8.128636121749878
# [Epoch: 7 - Training]
# [Batch: 20] running train loss: 0.5137, running train accuracy: 0.7539
# [Batch: 40] running train loss: 0.5023, running train accuracy: 0.7629
# [Batch: 60] running train loss: 0.5034, running train accuracy: 0.7630
# [Batch: 80] running train loss: 0.5007, running train accuracy: 0.7670
# [Batch: 100] running train loss: 0.4965, running train accuracy: 0.7706
# [Batch: 120] running train loss: 0.4981, running train accuracy: 0.7684
# [Batch: 140] running train loss: 0.4983, running train accuracy: 0.7692
# [Batch: 160] running train loss: 0.5012, running train accuracy: 0.7671
# [Batch: 180] running train loss: 0.4983, running train accuracy: 0.7701
# [Batch: 200] running train loss: 0.4953, running train accuracy: 0.7720
# [Batch: 220] running train loss: 0.4965, running train accuracy: 0.7709
# [Batch: 240] running train loss: 0.4947, running train accuracy: 0.7722
# train loss: 0.4947, accuracy: 0.7721
# elapsed time: 66.35694622993469
# [Test]
# [Batch: 1] running test loss: 0.4730, running test accuracy: 0.7969
# [Batch: 20] running test loss: 0.4328, running test accuracy: 0.8297
# test loss: 0.4263, accuracy: 0.8305
# elapsed time: 8.134080648422241
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.4763, running train accuracy: 0.7812
# [Batch: 40] running train loss: 0.4840, running train accuracy: 0.7797
# [Batch: 60] running train loss: 0.4877, running train accuracy: 0.7768
# [Batch: 80] running train loss: 0.4933, running train accuracy: 0.7740
# [Batch: 100] running train loss: 0.4928, running train accuracy: 0.7750
# [Batch: 120] running train loss: 0.4904, running train accuracy: 0.7747
# [Batch: 140] running train loss: 0.4905, running train accuracy: 0.7748
# [Batch: 160] running train loss: 0.4909, running train accuracy: 0.7727
# [Batch: 180] running train loss: 0.4899, running train accuracy: 0.7741
# [Batch: 200] running train loss: 0.4895, running train accuracy: 0.7742
# [Batch: 220] running train loss: 0.4901, running train accuracy: 0.7741
# [Batch: 240] running train loss: 0.4886, running train accuracy: 0.7755
# train loss: 0.4890, accuracy: 0.7751
# elapsed time: 62.38338828086853
# [Test]
# [Batch: 1] running test loss: 0.4607, running test accuracy: 0.7969
# [Batch: 20] running test loss: 0.4185, running test accuracy: 0.8336
# test loss: 0.4134, accuracy: 0.8320
# elapsed time: 7.549585819244385
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.4843, running train accuracy: 0.7789
# [Batch: 40] running train loss: 0.4875, running train accuracy: 0.7758
# [Batch: 60] running train loss: 0.4879, running train accuracy: 0.7781
# [Batch: 80] running train loss: 0.4865, running train accuracy: 0.7787
# [Batch: 100] running train loss: 0.4845, running train accuracy: 0.7788
# [Batch: 120] running train loss: 0.4790, running train accuracy: 0.7819
# [Batch: 140] running train loss: 0.4785, running train accuracy: 0.7819
# [Batch: 160] running train loss: 0.4774, running train accuracy: 0.7824
# [Batch: 180] running train loss: 0.4764, running train accuracy: 0.7834
# [Batch: 200] running train loss: 0.4764, running train accuracy: 0.7842
# [Batch: 220] running train loss: 0.4765, running train accuracy: 0.7833
# [Batch: 240] running train loss: 0.4768, running train accuracy: 0.7831
# train loss: 0.4763, accuracy: 0.7835
# elapsed time: 60.38131380081177
# [Test]
# [Batch: 1] running test loss: 0.4206, running test accuracy: 0.8281
# [Batch: 20] running test loss: 0.4158, running test accuracy: 0.8328
# test loss: 0.4116, accuracy: 0.8339
# elapsed time: 7.468488931655884
# [Epoch: 10 - Training]
# [Batch: 20] running train loss: 0.4786, running train accuracy: 0.7781
# [Batch: 40] running train loss: 0.4791, running train accuracy: 0.7781
# [Batch: 60] running train loss: 0.4767, running train accuracy: 0.7818
# [Batch: 80] running train loss: 0.4757, running train accuracy: 0.7812
# [Batch: 100] running train loss: 0.4712, running train accuracy: 0.7864
# [Batch: 120] running train loss: 0.4704, running train accuracy: 0.7879
# [Batch: 140] running train loss: 0.4685, running train accuracy: 0.7879
# [Batch: 160] running train loss: 0.4648, running train accuracy: 0.7900
# [Batch: 180] running train loss: 0.4647, running train accuracy: 0.7898
# [Batch: 200] running train loss: 0.4631, running train accuracy: 0.7897
# [Batch: 220] running train loss: 0.4623, running train accuracy: 0.7897
# [Batch: 240] running train loss: 0.4645, running train accuracy: 0.7885
# train loss: 0.4646, accuracy: 0.7885
# elapsed time: 60.554214000701904
# [Test]
# [Batch: 1] running test loss: 0.4159, running test accuracy: 0.7969
# [Batch: 20] running test loss: 0.4089, running test accuracy: 0.8320
# test loss: 0.4027, accuracy: 0.8373
# elapsed time: 7.5408642292022705

# %%
import matplotlib.pyplot as plt

train_losses, test_losses = zip(*history)
train_accuracies, test_accuracies = zip(*accuracy)

plt.figure(figsize=(13, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training & testing accuracieplt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Test Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
test_acc = evaluation(retrained_model, test_dataloader)
unseen_acc = evaluation(retrained_model, unseen_dataloader)
mia = cal_mia(retrained_model.cuda())
print()
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.403, 'Acc': 0.8373112518265953}
# Unseen Acc: {'Loss': 0.457, 'Acc': 0.7981009495252374}
# MIA: {'MIA': 0.545635910224439, 'Forgeting Score': 0.045635910224439025}
# Final Score: 0.8730197156888586
